# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
s0 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/states_0.npy') #og
s1 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/states_3.npy') #oc x and y
s2 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/states_1.npy')# oc x
s3 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/states_2.npy')# oc y

a = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/act.npy') 
a0 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/act_0.npy') #og
a1 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/act_1.npy') #oc x and y
a2 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/act_2.npy')# oc x
a3 = np.load('/home/ubuntu/siddhant/CompositionalKoopmanOperators/data/test/act_3.npy')# oc y

# %%
# plt.plot(s0[:,1,:2]-s2[:,1,:2])
plt.plot(s1[:,1,:1],label="OC x and y")
plt.plot(s2[:,1,:1],label="OC x")
plt.plot(s3[:,1,:1],label="OC y")
plt.plot(s0[:,1,:1],label="Original")
plt.legend()
# plt.plot(s1[:,0,:2]-s0[:,0,:2])

# %%
# plt.plot(s0[:,1,:2]-s2[:,1,:2])
plt.plot(s1[:,0,:1],label="OC x and y")
plt.plot(s2[:,0,:1],label="OC x")
plt.plot(s3[:,0,:1],label="OC y")
plt.plot(s0[:,0,:1],label="Original")
plt.legend()
# plt.plot(s1[:,0,:2]-s0[:,0,:2])

# %%
# plt.plot(s0[:,1,:2]-s2[:,1,:2])
plt.plot(a[:,0,0],label="Input")
plt.plot(a1[:,0,0],label="OC x and y")
plt.plot(a2[:,0,0],label="OC x")
plt.plot(a3[:,0,0],label="OC y")
plt.plot(a0[:,0,0],label="Original")
plt.legend()
# plt.plot(s1[:,0,:2]-s0[:,0,:2])

# %%
a0.shape
# Out:
# (101, 4, 1)
